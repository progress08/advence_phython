# %% [markdown]
# # Pandas Tasks

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# ### Task 3 - Create DataFrame

# %%
data = {
    'Name': ['John', 'Emma', 'Mike', 'Sara', 'Tom'],
    'Age': [19, 22, 20, 21, 18],
    'Score': [75, 88, 92, 67, 81]
}
df = pd.DataFrame(data)
df

# %% [markdown]
# ### Task 4 - Data Exploration

# %%
df.head(3)

# %%
df.describe()

# %%
df['Score'].mean()

# %% [markdown]
# ### Task 5 - Filtering

# %%
df[df['Age'] > 20]

# %%
df[df['Score'] > 80]
